# %% [markdown]
# ### Project setup (run this cell once)
#
# Run the cell below to copy the project files into your Google Drive.
#
# - When prompted to connect to Google Drive, click **Select all** and then **Allow**.
# - This cell saves the project files in your **Colab Notebooks** folder in Drive:
#   `My Drive / Colab Notebooks`.
#
# ### How to open the project notebooks (important)
#
# The **first time** you open each project notebook, you must do it from Google Drive:
#
# 1. Go to **https://drive.google.com/**.
# 2. In **My Drive → Colab Notebooks**, find:
#    - `cosmic_assign.ipynb`
#    - `cosmic_API_tests.ipynb`
#    - `cosmic_presentation.ipynb`
# 3. For each of these:
#    - Right-click the file → **Open with → Google Colaboratory**
#      (or double-click if it already defaults to Colab).
#
# After you have opened a notebook once from Drive, it will also appear in
# **Colab → File → Open notebook… → Recent** (and under the
# **Google Drive / Colab Notebooks** view), so you can open it from there next time.

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
import urllib.request

# All project files live here in your Google Drive
# PROJECT_DIR = "/content/drive/MyDrive/phys2600_cosmic_project"
PROJECT_DIR = "/content/drive/MyDrive/Colab Notebooks"
os.makedirs(PROJECT_DIR, exist_ok=True)

# %cd $PROJECT_DIR

remote_dir = "https://raw.githubusercontent.com/wlough/CU-Phys2600-Fall2025/main/final_projects/proj1_cosmic/"
filenames = [
    "cosmic_API_tests.ipynb",
    "cosmic_assign.ipynb",
    "cosmic_presentation.ipynb",
    "cosmic.py",
]

for filename in filenames:
    remote_url = remote_dir + filename
    local_path = os.path.join(PROJECT_DIR, filename)
    if not os.path.exists(local_path):
        print(f"Copying {filename} to {local_path}")
        urllib.request.urlretrieve(remote_url, local_path)
    else:
        print(f"{filename} already exists at {local_path}")
